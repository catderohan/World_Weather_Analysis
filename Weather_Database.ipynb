# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import sys
sys.path.append("..")

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3338f1eb6e0659d3b585d14c3d0e696f

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":47.46,"feels_like":43.74,"temp_min":42.01,"temp_max":53.01,"pressure":1030,"humidity":81},"visibility":10000,"wind":{"speed":3.36,"deg":160},"clouds":{"all":90},"dt":1603078505,"sys":{"type":1,"id":3486,"country":"US","sunrise":1603018857,"sunset":1603058237},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 47.46,
#   'feels_like': 43.74,
#   'temp_min': 42.01,
#   'temp_max': 53.01,
#   'pressure': 1030,
#   'humidity': 81},
#  'visibility': 10000,
#  'wind': {'speed': 3.36, 'deg': 160},
#  'clouds': {'all': 90},
#  'dt': 1603078505,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1603018857,
#   'sunset': 1603058237},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | plettenberg bay
# Processing Record 2 of Set 1 | almaznyy
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | maxixe
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | buala
# Processing Record 8 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | mae sai
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | port blair
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | pankrushikha
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | mount isa
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | santa rosa
# Processing Record 19 of Set 1 | umm kaddadah
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | salalah
# Processing Record 25 of Set 1 | yaransk
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | kirakira
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | awjilah
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | chifeng
# Processing Record 36 of Set 1 | dingle
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | poya
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | gamba
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | kalomo
# City not found. Skipping...
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | invermere
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | katherine
# Processing Record 4 of Set 2 | ploemeur
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | qui nhon
# Processing Record 9 of Set 2 | cayenne
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | matadi
# Processing Record 12 of Set 2 | hecun
# Processing Record 13 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | tokur
# Processing Record 16 of Set 2 | taksimo
# Processing Record 17 of Set 2 | yenagoa
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | bunia
# Processing Record 21 of Set 2 | ingham
# Processing Record 22 of Set 2 | kwinana
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | cortez
# Processing Record 28 of Set 2 | luena
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | qinzhou
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | itarema
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | boende
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | abalak
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | ridgecrest
# Processing Record 41 of Set 2 | jalingo
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | loreto
# Processing Record 44 of Set 2 | chara
# Processing Record 45 of Set 2 | tinjah
# City not found. Skipping...
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | saint-georges
# Processing Record 48 of Set 2 | havre-saint-pierre
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | victor harbor
# Processing Record 2 of Set 3 | rovaniemi
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | menongue
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | zaltan
# Processing Record 7 of Set 3 | asau
# Processing Record 8 of Set 3 | prieska
# Processing Record 9 of Set 3 | nabire
# Processing Record 10 of Set 3 | kpandae
# Processing Record 11 of Set 3 | poros
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | lensk
# Processing Record 14 of Set 3 | samarai
# Processing Record 15 of Set 3 | belyy yar
# Processing Record 16 of Set 3 | ahipara
# Processing Record 17 of Set 3 | volga
# Processing Record 18 of Set 3 | shimoda
# Processing Record 19 of Set 3 | pokanayevka
# City not found. Skipping...
# Processing Record 20 of Set 3 | honiara
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | marawi
# Processing Record 24 of Set 3 | mbandaka
# Processing Record 25 of Set 3 | vila velha
# Processing Record 26 of Set 3 | yuyao
# Processing Record 27 of Set 3 | namibe
# Processing Record 28 of Set 3 | tailai
# Processing Record 29 of Set 3 | saint anthony
# Processing Record 30 of Set 3 | chake chake
# Processing Record 31 of Set 3 | peterhead
# Processing Record 32 of Set 3 | vavuniya
# Processing Record 33 of Set 3 | concarneau
# Processing Record 34 of Set 3 | paamiut
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | saint-leu
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | jijiga
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | kiruna
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 3 | ushtobe
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | gambela
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | fort portal
# Processing Record 2 of Set 4 | sisimiut
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | khorixas
# Processing Record 5 of Set 4 | sorong
# Processing Record 6 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | faya
# Processing Record 9 of Set 4 | anta
# Processing Record 10 of Set 4 | hami
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | palaia fokaia
# Processing Record 13 of Set 4 | churapcha
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | oranjemund
# Processing Record 16 of Set 4 | broome
# Processing Record 17 of Set 4 | winslow
# Processing Record 18 of Set 4 | baykit
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | adrar
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | sitka
# Processing Record 25 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 4 | bosaso
# Processing Record 27 of Set 4 | luwuk
# Processing Record 28 of Set 4 | mantua
# Processing Record 29 of Set 4 | presidente olegario
# Processing Record 30 of Set 4 | tamiahua
# Processing Record 31 of Set 4 | erdemli
# Processing Record 32 of Set 4 | shahreza
# Processing Record 33 of Set 4 | jalu
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | naze
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | san francisco
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | novyye burasy
# Processing Record 42 of Set 4 | genhe
# Processing Record 43 of Set 4 | qaanaaq
# Processing Record 44 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 4 | ilheus
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | zhanaozen
# Processing Record 49 of Set 4 | te anau
# Processing Record 50 of Set 4 | mabaruma
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 5 | clocolan
# Processing Record 4 of Set 5 | alugan
# Processing Record 5 of Set 5 | hammond
# Processing Record 6 of Set 5 | belmonte
# Processing Record 7 of Set 5 | iranshahr
# Processing Record 8 of Set 5 | khandyga
# Processing Record 9 of Set 5 | kathmandu
# Processing Record 10 of Set 5 | pahrump
# Processing Record 11 of Set 5 | forest hills
# Processing Record 12 of Set 5 | rincon
# Processing Record 13 of Set 5 | tiruvottiyur
# City not found. Skipping...
# Processing Record 14 of Set 5 | sivas
# Processing Record 15 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 16 of Set 5 | cap malheureux
# Processing Record 17 of Set 5 | the pas
# Processing Record 18 of Set 5 | makakilo city
# Processing Record 19 of Set 5 | waitati
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | kysyl-syr
# Processing Record 22 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 5 | liangxiang
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | kalga
# Processing Record 26 of Set 5 | beloha
# Processing Record 27 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 5 | guerrero negro
# Processing Record 29 of Set 5 | tarakan
# Processing Record 30 of Set 5 | bereda
# Processing Record 31 of Set 5 | taoudenni
# Processing Record 32 of Set 5 | sorland
# Processing Record 33 of Set 5 | east london
# Processing Record 34 of Set 5 | bairiki
# Processing Record 35 of Set 5 | airai
# Processing Record 36 of Set 5 | maldonado
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | vostok
# Processing Record 39 of Set 5 | kaitong
# Processing Record 40 of Set 5 | samoded
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | sechura
# Processing Record 44 of Set 5 | mayumba
# Processing Record 45 of Set 5 | bilibino
# Processing Record 46 of Set 5 | marau
# Processing Record 47 of Set 5 | bonavista
# Processing Record 48 of Set 5 | sistranda
# Processing Record 49 of Set 5 | hualmay
# Processing Record 50 of Set 5 | mujiayingzi
# Processing Record 1 of Set 6 | odweyne
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | rodrigues alves
# Processing Record 4 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | tautira
# Processing Record 9 of Set 6 | lavrentiya
# Processing Record 10 of Set 6 | bridlington
# Processing Record 11 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | raga
# Processing Record 15 of Set 6 | morgan city
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | jacareacanga
# Processing Record 18 of Set 6 | deputatskiy
# Processing Record 19 of Set 6 | melita
# Processing Record 20 of Set 6 | chumikan
# Processing Record 21 of Set 6 | kiama
# Processing Record 22 of Set 6 | kisumu
# Processing Record 23 of Set 6 | cocorit
# Processing Record 24 of Set 6 | neiafu
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | vaitape
# Processing Record 27 of Set 6 | corning
# Processing Record 28 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 6 | galesong
# Processing Record 30 of Set 6 | muros
# Processing Record 31 of Set 6 | evensk
# Processing Record 32 of Set 6 | sur
# Processing Record 33 of Set 6 | altay
# Processing Record 34 of Set 6 | saint paul
# Processing Record 35 of Set 6 | lodwar
# Processing Record 36 of Set 6 | maniitsoq
# Processing Record 37 of Set 6 | meghri
# Processing Record 38 of Set 6 | iaciara
# Processing Record 39 of Set 6 | wyndham
# Processing Record 40 of Set 6 | christchurch
# Processing Record 41 of Set 6 | bubaque
# Processing Record 42 of Set 6 | camacha
# Processing Record 43 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | nemuro
# Processing Record 46 of Set 6 | kropotkin
# Processing Record 47 of Set 6 | mwinilunga
# Processing Record 48 of Set 6 | altus
# Processing Record 49 of Set 6 | bambous virieux
# Processing Record 50 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 1 of Set 7 | zwedru
# Processing Record 2 of Set 7 | pangnirtung
# Processing Record 3 of Set 7 | fort abbas
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | katsuura
# Processing Record 6 of Set 7 | longyearbyen
# Processing Record 7 of Set 7 | krutinka
# Processing Record 8 of Set 7 | dicabisagan
# Processing Record 9 of Set 7 | dakar
# Processing Record 10 of Set 7 | aasiaat
# Processing Record 11 of Set 7 | bambanglipuro
# Processing Record 12 of Set 7 | owando
# Processing Record 13 of Set 7 | fukue
# Processing Record 14 of Set 7 | nuuk
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | trairi
# Processing Record 17 of Set 7 | nome
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | tomatlan
# Processing Record 20 of Set 7 | itambe
# Processing Record 21 of Set 7 | uk
# City not found. Skipping...
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | novobiryusinskiy
# Processing Record 25 of Set 7 | rio gallegos
# Processing Record 26 of Set 7 | ban phai
# Processing Record 27 of Set 7 | scarborough
# Processing Record 28 of Set 7 | kualakapuas
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | hobyo
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | altagracia de orituco
# Processing Record 33 of Set 7 | vao
# Processing Record 34 of Set 7 | waingapu
# Processing Record 35 of Set 7 | kurya
# Processing Record 36 of Set 7 | dikson
# Processing Record 37 of Set 7 | choya
# Processing Record 38 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 7 | murud
# Processing Record 40 of Set 7 | thompson
# Processing Record 41 of Set 7 | carnaiba
# Processing Record 42 of Set 7 | tahe
# Processing Record 43 of Set 7 | praia da vitoria
# Processing Record 44 of Set 7 | boxmeer
# Processing Record 45 of Set 7 | falun
# Processing Record 46 of Set 7 | kruisfontein
# Processing Record 47 of Set 7 | dukat
# Processing Record 48 of Set 7 | salinas
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | kamloops
# Processing Record 1 of Set 8 | pedraza
# Processing Record 2 of Set 8 | lata
# Processing Record 3 of Set 8 | havoysund
# Processing Record 4 of Set 8 | king city
# Processing Record 5 of Set 8 | tabou
# Processing Record 6 of Set 8 | andenes
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | muyezerskiy
# Processing Record 9 of Set 8 | atikokan
# Processing Record 10 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 8 | biak
# Processing Record 12 of Set 8 | newport
# Processing Record 13 of Set 8 | mattru
# Processing Record 14 of Set 8 | labuan
# Processing Record 15 of Set 8 | les cayes
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | lasa
# Processing Record 18 of Set 8 | veraval
# Processing Record 19 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | wanning
# Processing Record 21 of Set 8 | amatitan
# Processing Record 22 of Set 8 | yerbogachen
# Processing Record 23 of Set 8 | warren
# Processing Record 24 of Set 8 | mahajanga
# Processing Record 25 of Set 8 | bilma
# Processing Record 26 of Set 8 | nanortalik
# Processing Record 27 of Set 8 | ryotsu
# Processing Record 28 of Set 8 | birjand
# Processing Record 29 of Set 8 | beyneu
# Processing Record 30 of Set 8 | halifax
# Processing Record 31 of Set 8 | kutum
# Processing Record 32 of Set 8 | iqaluit
# Processing Record 33 of Set 8 | nantucket
# Processing Record 34 of Set 8 | colchester
# Processing Record 35 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 8 | chiman
# Processing Record 37 of Set 8 | roma
# Processing Record 38 of Set 8 | klyuchi
# Processing Record 39 of Set 8 | tiksi
# Processing Record 40 of Set 8 | tanout
# Processing Record 41 of Set 8 | kaeo
# Processing Record 42 of Set 8 | winburg
# Processing Record 43 of Set 8 | balfour
# Processing Record 44 of Set 8 | hervey bay
# Processing Record 45 of Set 8 | esperance
# Processing Record 46 of Set 8 | bagan
# Processing Record 47 of Set 8 | kambia
# Processing Record 48 of Set 8 | belawan
# Processing Record 49 of Set 8 | marsa matruh
# Processing Record 50 of Set 8 | ulladulla
# Processing Record 1 of Set 9 | manado
# Processing Record 2 of Set 9 | lekoni
# Processing Record 3 of Set 9 | barkhan
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | kaiyuan
# Processing Record 6 of Set 9 | polunochnoye
# Processing Record 7 of Set 9 | zhaoyuan
# Processing Record 8 of Set 9 | carnarvon
# Processing Record 9 of Set 9 | barinas
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | mahon
# Processing Record 12 of Set 9 | santa cruz
# Processing Record 13 of Set 9 | druzhba
# Processing Record 14 of Set 9 | montemurlo
# Processing Record 15 of Set 9 | imeni poliny osipenko
# Processing Record 16 of Set 9 | arraias
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | cabo san lucas
# Processing Record 19 of Set 9 | geraldton
# Processing Record 20 of Set 9 | lakes entrance
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | quibdo
# Processing Record 23 of Set 9 | burns lake
# Processing Record 24 of Set 9 | wokha
# Processing Record 25 of Set 9 | gigmoto
# Processing Record 26 of Set 9 | midrand
# Processing Record 27 of Set 9 | nekrasovka
# Processing Record 28 of Set 9 | dargaville
# Processing Record 29 of Set 9 | stokmarknes
# Processing Record 30 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 9 | bad essen
# Processing Record 32 of Set 9 | dzhankoy
# Processing Record 33 of Set 9 | shcholkine
# City not found. Skipping...
# Processing Record 34 of Set 9 | moranbah
# Processing Record 35 of Set 9 | sampit
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 9 | klaksvik
# Processing Record 39 of Set 9 | marienburg
# Processing Record 40 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 9 | egvekinot
# Processing Record 42 of Set 9 | solnechnyy
# Processing Record 43 of Set 9 | nongpoh
# Processing Record 44 of Set 9 | lubumbashi
# Processing Record 45 of Set 9 | pochutla
# Processing Record 46 of Set 9 | andira
# Processing Record 47 of Set 9 | juli
# Processing Record 48 of Set 9 | dudinka
# Processing Record 49 of Set 9 | nobres
# Processing Record 50 of Set 9 | tezu
# Processing Record 1 of Set 10 | kilindoni
# Processing Record 2 of Set 10 | xai-xai
# Processing Record 3 of Set 10 | pacific grove
# Processing Record 4 of Set 10 | kargat
# Processing Record 5 of Set 10 | hazorasp
# Processing Record 6 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 10 | ballina
# Processing Record 8 of Set 10 | santa cruz de la palma
# Processing Record 9 of Set 10 | tilichiki
# Processing Record 10 of Set 10 | igarka
# Processing Record 11 of Set 10 | liverpool
# Processing Record 12 of Set 10 | miguel hidalgo
# Processing Record 13 of Set 10 | hurricane
# Processing Record 14 of Set 10 | hofn
# Processing Record 15 of Set 10 | novyy urengoy
# Processing Record 16 of Set 10 | mitchell
# Processing Record 17 of Set 10 | khani
# Processing Record 18 of Set 10 | morro bay
# Processing Record 19 of Set 10 | nurota
# Processing Record 20 of Set 10 | bandarbeyla
# Processing Record 21 of Set 10 | fort-shevchenko
# Processing Record 22 of Set 10 | veranopolis
# Processing Record 23 of Set 10 | viransehir
# Processing Record 24 of Set 10 | port shepstone
# Processing Record 25 of Set 10 | muskogee
# Processing Record 26 of Set 10 | estelle
# Processing Record 27 of Set 10 | walvis bay
# Processing Record 28 of Set 10 | madimba
# Processing Record 29 of Set 10 | mount gambier
# Processing Record 30 of Set 10 | eureka
# Processing Record 31 of Set 10 | dunedin
# Processing Record 32 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 10 | concordia
# Processing Record 34 of Set 10 | fort smith
# Processing Record 35 of Set 10 | mecca
# Processing Record 36 of Set 10 | san carlos
# Processing Record 37 of Set 10 | atambua
# Processing Record 38 of Set 10 | hit
# Processing Record 39 of Set 10 | port hedland
# Processing Record 40 of Set 10 | bilaspur
# Processing Record 41 of Set 10 | pierre
# Processing Record 42 of Set 10 | victoria
# Processing Record 43 of Set 10 | acandi
# Processing Record 44 of Set 10 | san juan del sur
# Processing Record 45 of Set 10 | san jose
# Processing Record 46 of Set 10 | kaihua
# Processing Record 47 of Set 10 | semibratovo
# Processing Record 48 of Set 10 | avera
# Processing Record 49 of Set 10 | padang
# Processing Record 50 of Set 10 | quatre cocos
# Processing Record 1 of Set 11 | esmeraldas
# Processing Record 2 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 3 of Set 11 | yarmouth
# Processing Record 4 of Set 11 | san patricio
# Processing Record 5 of Set 11 | vestmanna
# Processing Record 6 of Set 11 | abu kamal
# Processing Record 7 of Set 11 | saint-augustin
# Processing Record 8 of Set 11 | grand gaube
# Processing Record 9 of Set 11 | strai
# Processing Record 10 of Set 11 | veinticinco de mayo
# Processing Record 11 of Set 11 | sao felix do xingu
# Processing Record 12 of Set 11 | storforshei
# Processing Record 13 of Set 11 | superior
# Processing Record 14 of Set 11 | potgietersrus
# City not found. Skipping...
# Processing Record 15 of Set 11 | ende
# Processing Record 16 of Set 11 | katobu
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | abu samrah
# Processing Record 19 of Set 11 | srednekolymsk
# Processing Record 20 of Set 11 | pryazha
# Processing Record 21 of Set 11 | pangani
# Processing Record 22 of Set 11 | kasama
# Processing Record 23 of Set 11 | yumen
# Processing Record 24 of Set 11 | yelizovo
# Processing Record 25 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 11 | kota tinggi
# Processing Record 27 of Set 11 | westerland
# Processing Record 28 of Set 11 | sawakin
# Processing Record 29 of Set 11 | moose factory
# Processing Record 30 of Set 11 | iskateley
# Processing Record 31 of Set 11 | burnie
# Processing Record 32 of Set 11 | portland
# Processing Record 33 of Set 11 | diego de almagro
# Processing Record 34 of Set 11 | barreirinha
# Processing Record 35 of Set 11 | shilovo
# Processing Record 36 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 11 | chalon-sur-saone
# Processing Record 40 of Set 11 | bonfim
# Processing Record 41 of Set 11 | panalingaan
# Processing Record 42 of Set 11 | mokhsogollokh
# Processing Record 43 of Set 11 | goderich
# Processing Record 44 of Set 11 | morehead
# Processing Record 45 of Set 11 | ulaanbaatar
# Processing Record 46 of Set 11 | provideniya
# Processing Record 47 of Set 11 | batagay-alyta
# Processing Record 48 of Set 11 | vardo
# Processing Record 49 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 11 | rio grande
# Processing Record 1 of Set 12 | vanimo
# Processing Record 2 of Set 12 | isangel
# Processing Record 3 of Set 12 | aksu
# Processing Record 4 of Set 12 | yokadouma
# Processing Record 5 of Set 12 | sakakah
# Processing Record 6 of Set 12 | viljoenskroon
# Processing Record 7 of Set 12 | pyaozerskiy
# Processing Record 8 of Set 12 | aykhal
# Processing Record 9 of Set 12 | arbuzynka
# Processing Record 10 of Set 12 | dwarka
# Processing Record 11 of Set 12 | azangaro
# Processing Record 12 of Set 12 | tonami
# Processing Record 13 of Set 12 | kyaikto
# Processing Record 14 of Set 12 | chippewa falls
# Processing Record 15 of Set 12 | parana
# Processing Record 16 of Set 12 | khvoynaya
# Processing Record 17 of Set 12 | skibbereen
# Processing Record 18 of Set 12 | ipixuna
# Processing Record 19 of Set 12 | boljarovo
# City not found. Skipping...
# Processing Record 20 of Set 12 | fort nelson
# Processing Record 21 of Set 12 | hauterive
# Processing Record 22 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 12 | kavaratti
# Processing Record 24 of Set 12 | pattukkottai
# Processing Record 25 of Set 12 | rio de janeiro
# Processing Record 26 of Set 12 | narsaq
# Processing Record 27 of Set 12 | berlevag
# Processing Record 28 of Set 12 | pavlovsk
# Processing Record 29 of Set 12 | davila
# Processing Record 30 of Set 12 | turukhansk
# Processing Record 31 of Set 12 | alamos
# Processing Record 32 of Set 12 | comodoro rivadavia
# Processing Record 33 of Set 12 | nandgaon
# Processing Record 34 of Set 12 | kurilsk
# Processing Record 35 of Set 12 | balikpapan
# Processing Record 36 of Set 12 | yining
# Processing Record 37 of Set 12 | moron
# Processing Record 38 of Set 12 | balkhash
# Processing Record 39 of Set 12 | sayyan
# Processing Record 40 of Set 12 | sooke
# Processing Record 41 of Set 12 | gat
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | muisne
# Processing Record 44 of Set 12 | guozhen
# Processing Record 45 of Set 12 | goba
# Processing Record 46 of Set 12 | calatayud
# Processing Record 47 of Set 12 | cedar lake
# Processing Record 48 of Set 12 | duayaw nkwanta
# Processing Record 49 of Set 12 | verkhnyaya sinyachikha
# Processing Record 50 of Set 12 | tiarei
# Processing Record 1 of Set 13 | baicheng
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | auki
# Processing Record 4 of Set 13 | arlit
# Processing Record 5 of Set 13 | mitsamiouli
# Processing Record 6 of Set 13 | oksfjord
# Processing Record 7 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 8 of Set 13 | vila
# Processing Record 9 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 13 | nizhniy kuranakh
# Processing Record 11 of Set 13 | trat
# Processing Record 12 of Set 13 | adelaide
# Processing Record 13 of Set 13 | phalaborwa
# Processing Record 14 of Set 13 | zharkent
# Processing Record 15 of Set 13 | stykkisholmur
# Processing Record 16 of Set 13 | tateyama
# Processing Record 17 of Set 13 | leshukonskoye
# Processing Record 18 of Set 13 | la libertad
# Processing Record 19 of Set 13 | rio cuarto
# Processing Record 20 of Set 13 | northam
# Processing Record 21 of Set 13 | da nang
# Processing Record 22 of Set 13 | san carlos de bariloche
# Processing Record 23 of Set 13 | tyukalinsk
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | clyde river
# Processing Record 26 of Set 13 | tongsa
# City not found. Skipping...
# Processing Record 27 of Set 13 | kasempa
# Processing Record 28 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | tonj
# Processing Record 30 of Set 13 | buraydah
# Processing Record 31 of Set 13 | xiaoweizhai
# Processing Record 32 of Set 13 | antofagasta
# Processing Record 33 of Set 13 | mayo
# Processing Record 34 of Set 13 | ixtapa
# Processing Record 35 of Set 13 | poum
# Processing Record 36 of Set 13 | lingao
# Processing Record 37 of Set 13 | benalla
# Processing Record 38 of Set 13 | luganville
# Processing Record 39 of Set 13 | morondava
# Processing Record 40 of Set 13 | soyo
# Processing Record 41 of Set 13 | erzin
# Processing Record 42 of Set 13 | calatrava
# Processing Record 43 of Set 13 | kazachka
# Processing Record 44 of Set 13 | alta floresta
# Processing Record 45 of Set 13 | garachine
# Processing Record 46 of Set 13 | yanam
# Processing Record 47 of Set 13 | mabamba
# Processing Record 48 of Set 13 | yar-sale
# Processing Record 49 of Set 13 | matiompong
# Processing Record 50 of Set 13 | maceio
# Processing Record 1 of Set 14 | turtas
# Processing Record 2 of Set 14 | ekhabi
# Processing Record 3 of Set 14 | celestun
# Processing Record 4 of Set 14 | clarksville
# Processing Record 5 of Set 14 | parrita
# Processing Record 6 of Set 14 | morganton
# Processing Record 7 of Set 14 | beni
# Processing Record 8 of Set 14 | pinega
# Processing Record 9 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 14 | garm
# City not found. Skipping...
# Processing Record 12 of Set 14 | dire dawa
# Processing Record 13 of Set 14 | kichmengskiy gorodok
# Processing Record 14 of Set 14 | axim
# Processing Record 15 of Set 14 | port-cartier
# Processing Record 16 of Set 14 | daru
# Processing Record 17 of Set 14 | kabare
# Processing Record 18 of Set 14 | mangrol
# Processing Record 19 of Set 14 | mangit
# Processing Record 20 of Set 14 | eugene
# Processing Record 21 of Set 14 | kitami
# Processing Record 22 of Set 14 | coronado
# Processing Record 23 of Set 14 | sola
# Processing Record 24 of Set 14 | aswan
# Processing Record 25 of Set 14 | pinheiro machado
# Processing Record 26 of Set 14 | storrs
# Processing Record 27 of Set 14 | kouqian
# Processing Record 28 of Set 14 | tual
# Processing Record 29 of Set 14 | champerico
# Processing Record 30 of Set 14 | mkushi
# Processing Record 31 of Set 14 | shache
# Processing Record 32 of Set 14 | sabang
# Processing Record 33 of Set 14 | mogadishu
# Processing Record 34 of Set 14 | limbang
# Processing Record 35 of Set 14 | santiago del estero
# Processing Record 36 of Set 14 | methoni
# Processing Record 37 of Set 14 | ayna
# Processing Record 38 of Set 14 | monticello
# Processing Record 39 of Set 14 | finnsnes
# Processing Record 40 of Set 14 | itamarandiba
# Processing Record 41 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 14 | adwa
# Processing Record 44 of Set 14 | kimbe
# Processing Record 45 of Set 14 | frederico westphalen
# Processing Record 46 of Set 14 | krasnoturinsk
# Processing Record 47 of Set 14 | acajutla
# Processing Record 48 of Set 14 | inhambane
# Processing Record 49 of Set 14 | vitim
# Processing Record 50 of Set 14 | antsirabe
# Processing Record 1 of Set 15 | bathurst
# Processing Record 2 of Set 15 | pauini
# Processing Record 3 of Set 15 | pontianak
# Processing Record 4 of Set 15 | alghero
# Processing Record 5 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | santa vitoria
# Processing Record 7 of Set 15 | kasongo
# Processing Record 8 of Set 15 | hasaki
# Processing Record 9 of Set 15 | kaspiyskiy
# Processing Record 10 of Set 15 | castro verde
# Processing Record 11 of Set 15 | bolshaya rechka
# Processing Record 12 of Set 15 | winchester
# Processing Record 13 of Set 15 | camabatela
# Processing Record 14 of Set 15 | ostersund
# Processing Record 15 of Set 15 | talesh
# City not found. Skipping...
# Processing Record 16 of Set 15 | ponta delgada
# Processing Record 17 of Set 15 | erenhot
# Processing Record 18 of Set 15 | williams lake
# Processing Record 19 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 15 | riviera beach
# Processing Record 21 of Set 15 | dera din panah
# City not found. Skipping...
# Processing Record 22 of Set 15 | zeya
# Processing Record 23 of Set 15 | seoul
# Processing Record 24 of Set 15 | ostrozska nova ves
# Processing Record 25 of Set 15 | hammerfest
# Processing Record 26 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 15 | roros
# Processing Record 28 of Set 15 | olinda
# Processing Record 29 of Set 15 | junin
# Processing Record 30 of Set 15 | hohhot
# Processing Record 31 of Set 15 | zemio
# Processing Record 32 of Set 15 | londa
# Processing Record 33 of Set 15 | wildberg
# Processing Record 34 of Set 15 | susanville
# Processing Record 35 of Set 15 | caravelas
# Processing Record 36 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 15 | volos
# Processing Record 38 of Set 15 | male
# Processing Record 39 of Set 15 | strezhevoy
# Processing Record 40 of Set 15 | binzhou
# Processing Record 41 of Set 15 | tabuk
# Processing Record 42 of Set 15 | port hawkesbury
# Processing Record 43 of Set 15 | krasnoselkup
# Processing Record 44 of Set 15 | lagoa
# Processing Record 45 of Set 15 | tubinskiy
# Processing Record 46 of Set 15 | jiazi
# Processing Record 47 of Set 15 | alenquer
# Processing Record 48 of Set 15 | waynesville
# Processing Record 49 of Set 15 | krabi
# Processing Record 50 of Set 15 | ratnagiri
# Processing Record 1 of Set 16 | miranda
# Processing Record 2 of Set 16 | bridgetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Plettenberg Bay -34.05   23.37     57.29        78          99        2.15
# 1         Almaznyy  48.04   40.05     53.60        66         100        6.71
# 2           Barrow  71.29 -156.79     23.00        79          90       14.99
# 3           Maxixe -23.86   35.35     69.64        78           0        4.14
# 4          Ushuaia -54.80  -68.30     37.40        74          20       16.11
# 5      Port Alfred -33.59   26.89     60.64        84          70        3.18
# 6            Buala  -8.14  159.59     85.68        69          32        4.97
# 7       Butaritari   3.07  172.79     82.04        72          35       15.84
# 8          Mae Sai  20.43   99.88     73.40        88          40        9.17
# 9       Port Blair  11.67   92.75     82.53        81          99       18.28
#
#   Country                 Date       Description
# 0      ZA  2020-10-19 03:39:19   overcast clouds
# 1      RU  2020-10-19 03:39:20   overcast clouds
# 2      US  2020-10-19 03:35:04   overcast clouds
# 3      MZ  2020-10-19 03:39:20         clear sky
# 4      AR  2020-10-19 03:35:09        few clouds
# 5      ZA  2020-10-19 03:39:21     broken clouds
# 6      SB  2020-10-19 03:36:03        light rain
# 7      KI  2020-10-19 03:39:22  scattered clouds
# 8      TH  2020-10-19 03:39:22  scattered clouds
# 9      IN  2020-10-19 03:39:23     moderate rain

# %%
city_data_df.to_csv('weather_database\WeatherPy_Database.csv', index = "False")
