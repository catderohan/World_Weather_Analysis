# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3338f1eb6e0659d3b585d14c3d0e696f

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":59.18,"feels_like":51.46,"temp_min":57.2,"temp_max":61,"pressure":1034,"humidity":58},"visibility":10000,"wind":{"speed":11.41,"deg":80},"clouds":{"all":75},"dt":1603042019,"sys":{"type":1,"id":3486,"country":"US","sunrise":1603018857,"sunset":1603058237},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 59.18,
#   'feels_like': 51.46,
#   'temp_min': 57.2,
#   'temp_max': 61,
#   'pressure': 1034,
#   'humidity': 58},
#  'visibility': 10000,
#  'wind': {'speed': 11.41, 'deg': 80},
#  'clouds': {'all': 75},
#  'dt': 1603042019,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1603018857,
#   'sunset': 1603058237},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})
                        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | camalu
# Processing Record 5 of Set 1 | roebourne
# Processing Record 6 of Set 1 | springfield
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | vao
# Processing Record 9 of Set 1 | asosa
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | alofi
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | vila velha
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | golspie
# Processing Record 18 of Set 1 | ossora
# Processing Record 19 of Set 1 | faya
# Processing Record 20 of Set 1 | upernavik
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | bayir
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | axim
# Processing Record 25 of Set 1 | cockburn town
# Processing Record 26 of Set 1 | husavik
# Processing Record 27 of Set 1 | hilton head island
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | tazovskiy
# Processing Record 31 of Set 1 | yeppoon
# Processing Record 32 of Set 1 | sinop
# Processing Record 33 of Set 1 | east hemet
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | pombos
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | berlevag
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | uhlove
# Processing Record 41 of Set 1 | stovring
# Processing Record 42 of Set 1 | udachnyy
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | tabas
# Processing Record 46 of Set 1 | tezu
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | fort-shevchenko
# Processing Record 3 of Set 2 | sola
# Processing Record 4 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 2 | kantunilkin
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | whitecourt
# Processing Record 8 of Set 2 | baijiantan
# Processing Record 9 of Set 2 | morant bay
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | amazar
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | bonavista
# Processing Record 15 of Set 2 | broken hill
# Processing Record 16 of Set 2 | xingcheng
# Processing Record 17 of Set 2 | marawi
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | labuhan
# Processing Record 20 of Set 2 | riyadh
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | cayenne
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | half moon bay
# Processing Record 25 of Set 2 | maldonado
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | orikum
# Processing Record 29 of Set 2 | padang
# Processing Record 30 of Set 2 | shu
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | komsomolskiy
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | phek
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | lagoa vermelha
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | jinchang
# Processing Record 42 of Set 2 | bartica
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | diego de almagro
# Processing Record 45 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 2 | aykhal
# Processing Record 47 of Set 2 | tawang
# Processing Record 48 of Set 2 | solnechnyy
# Processing Record 49 of Set 2 | evensk
# Processing Record 50 of Set 2 | natal
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | helena
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | mwinilunga
# Processing Record 6 of Set 3 | niquero
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | plastun
# Processing Record 9 of Set 3 | college
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | jambi
# Processing Record 14 of Set 3 | misawa
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | bossembele
# City not found. Skipping...
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | polonnaruwa
# Processing Record 20 of Set 3 | idrinskoye
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | petukhovo
# Processing Record 25 of Set 3 | ouadda
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | banff
# Processing Record 28 of Set 3 | dawlatabad
# Processing Record 29 of Set 3 | bollnas
# Processing Record 30 of Set 3 | lavrentiya
# Processing Record 31 of Set 3 | ulladulla
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | beni
# Processing Record 36 of Set 3 | kropotkin
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | sur
# Processing Record 39 of Set 3 | conde
# Processing Record 40 of Set 3 | fatehabad
# Processing Record 41 of Set 3 | molchanovo
# Processing Record 42 of Set 3 | markova
# Processing Record 43 of Set 3 | sal rei
# Processing Record 44 of Set 3 | honiara
# Processing Record 45 of Set 3 | along
# Processing Record 46 of Set 3 | chara
# Processing Record 47 of Set 3 | gumdag
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | waitati
# Processing Record 1 of Set 4 | san jose
# Processing Record 2 of Set 4 | camacha
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | pimenta bueno
# Processing Record 5 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | tual
# Processing Record 8 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | camocim
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | kavieng
# Processing Record 13 of Set 4 | okato
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | dunedin
# Processing Record 17 of Set 4 | cabra
# Processing Record 18 of Set 4 | changji
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | jurado
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | kurumkan
# Processing Record 24 of Set 4 | noumea
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 4 | new norfolk
# Processing Record 28 of Set 4 | xinxiang
# Processing Record 29 of Set 4 | oktyabrskiy
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | vestmannaeyjar
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | pedasi
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | grand-santi
# Processing Record 38 of Set 4 | sabha
# Processing Record 39 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 4 | lalibela
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | geraldton
# Processing Record 43 of Set 4 | port pirie
# Processing Record 44 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 4 | bani walid
# Processing Record 46 of Set 4 | sungaipenuh
# Processing Record 47 of Set 4 | gigmoto
# Processing Record 48 of Set 4 | sterling heights
# Processing Record 49 of Set 4 | kirovskiy
# Processing Record 50 of Set 4 | beian
# Processing Record 1 of Set 5 | taldan
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | talaya
# Processing Record 4 of Set 5 | cap malheureux
# Processing Record 5 of Set 5 | oneida
# Processing Record 6 of Set 5 | chardara
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | giehun
# Processing Record 9 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 5 | kailua
# Processing Record 11 of Set 5 | thompson
# Processing Record 12 of Set 5 | salalah
# Processing Record 13 of Set 5 | kholodnyy
# Processing Record 14 of Set 5 | ngunguru
# Processing Record 15 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 5 | oriximina
# Processing Record 17 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 5 | rio branco
# Processing Record 19 of Set 5 | najran
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | tabuk
# Processing Record 23 of Set 5 | hobyo
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | mount isa
# Processing Record 26 of Set 5 | santa lucia
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | nyaunglebin
# Processing Record 29 of Set 5 | krasnyy chikoy
# Processing Record 30 of Set 5 | nizwa
# Processing Record 31 of Set 5 | zhigansk
# Processing Record 32 of Set 5 | byron bay
# Processing Record 33 of Set 5 | urumqi
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | khandyga
# Processing Record 36 of Set 5 | chapais
# Processing Record 37 of Set 5 | harlingen
# Processing Record 38 of Set 5 | ponta do sol
# Processing Record 39 of Set 5 | brownsville
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | kisangani
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | lazurne
# Processing Record 44 of Set 5 | el badari
# City not found. Skipping...
# Processing Record 45 of Set 5 | temyasovo
# Processing Record 46 of Set 5 | bitadton
# Processing Record 47 of Set 5 | biak
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | kholmy
# Processing Record 50 of Set 5 | vilhena
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | kitimat
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | belyy yar
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | le port
# Processing Record 9 of Set 6 | tianpeng
# Processing Record 10 of Set 6 | belaya gora
# Processing Record 11 of Set 6 | uberlandia
# Processing Record 12 of Set 6 | san-pedro
# Processing Record 13 of Set 6 | hervey bay
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | nichinan
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | pasighat
# Processing Record 18 of Set 6 | dungarvan
# Processing Record 19 of Set 6 | linden
# Processing Record 20 of Set 6 | lagos
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | sao jose da coroa grande
# Processing Record 23 of Set 6 | yamada
# Processing Record 24 of Set 6 | bardiyah
# Processing Record 25 of Set 6 | russell
# Processing Record 26 of Set 6 | bell ville
# Processing Record 27 of Set 6 | naryan-mar
# Processing Record 28 of Set 6 | teya
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | pringsewu
# Processing Record 32 of Set 6 | yar-sale
# Processing Record 33 of Set 6 | aksu
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | kushmurun
# Processing Record 36 of Set 6 | bauchi
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | miro khan
# Processing Record 39 of Set 6 | mungwi
# Processing Record 40 of Set 6 | deputatskiy
# Processing Record 41 of Set 6 | hermanus
# Processing Record 42 of Set 6 | arlit
# Processing Record 43 of Set 6 | olden
# Processing Record 44 of Set 6 | asfi
# Processing Record 45 of Set 6 | bambanglipuro
# Processing Record 46 of Set 6 | verkhnyaya toyma
# Processing Record 47 of Set 6 | shelburne
# Processing Record 48 of Set 6 | constitucion
# Processing Record 49 of Set 6 | tura
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | maningrida
# Processing Record 2 of Set 7 | sorland
# Processing Record 3 of Set 7 | kapoeta
# Processing Record 4 of Set 7 | almaznyy
# Processing Record 5 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 7 | tiarei
# Processing Record 7 of Set 7 | port-gentil
# Processing Record 8 of Set 7 | jumla
# Processing Record 9 of Set 7 | anzegem
# Processing Record 10 of Set 7 | portland
# Processing Record 11 of Set 7 | guiratinga
# Processing Record 12 of Set 7 | marfino
# Processing Record 13 of Set 7 | demba
# Processing Record 14 of Set 7 | aguimes
# Processing Record 15 of Set 7 | el alto
# Processing Record 16 of Set 7 | yaan
# Processing Record 17 of Set 7 | rincon
# Processing Record 18 of Set 7 | broome
# Processing Record 19 of Set 7 | manta
# Processing Record 20 of Set 7 | usinsk
# Processing Record 21 of Set 7 | kuloy
# Processing Record 22 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 7 | porangatu
# Processing Record 25 of Set 7 | ribeira grande
# Processing Record 26 of Set 7 | beira
# Processing Record 27 of Set 7 | cerritos
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | belmonte
# Processing Record 30 of Set 7 | pisticci
# Processing Record 31 of Set 7 | jiuquan
# Processing Record 32 of Set 7 | paamiut
# Processing Record 33 of Set 7 | leningradskiy
# Processing Record 34 of Set 7 | haines junction
# Processing Record 35 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 7 | arman
# Processing Record 37 of Set 7 | fort saint james
# Processing Record 38 of Set 7 | norman wells
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | fort nelson
# Processing Record 41 of Set 7 | bethanien
# Processing Record 42 of Set 7 | latung
# Processing Record 43 of Set 7 | wanderlandia
# City not found. Skipping...
# Processing Record 44 of Set 7 | beloit
# Processing Record 45 of Set 7 | clearwater
# Processing Record 46 of Set 7 | namatanai
# Processing Record 47 of Set 7 | jakar
# Processing Record 48 of Set 7 | avadi
# Processing Record 49 of Set 7 | mackay
# Processing Record 50 of Set 7 | santa cruz de tenerife
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | ena
# Processing Record 3 of Set 8 | port macquarie
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | ostrovnoy
# Processing Record 6 of Set 8 | radlje ob dravi
# Processing Record 7 of Set 8 | champerico
# Processing Record 8 of Set 8 | dergaon
# Processing Record 9 of Set 8 | saint george
# Processing Record 10 of Set 8 | urubicha
# Processing Record 11 of Set 8 | yura
# Processing Record 12 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 8 | veraval
# Processing Record 15 of Set 8 | aripuana
# Processing Record 16 of Set 8 | rorvik
# Processing Record 17 of Set 8 | taltal
# Processing Record 18 of Set 8 | grand gaube
# Processing Record 19 of Set 8 | lima
# Processing Record 20 of Set 8 | mazamari
# Processing Record 21 of Set 8 | marzuq
# Processing Record 22 of Set 8 | bengkulu
# Processing Record 23 of Set 8 | vila
# Processing Record 24 of Set 8 | grindavik
# Processing Record 25 of Set 8 | sandpoint
# Processing Record 26 of Set 8 | qasigiannguit
# Processing Record 27 of Set 8 | torbay
# Processing Record 28 of Set 8 | coquimbo
# Processing Record 29 of Set 8 | ambon
# Processing Record 30 of Set 8 | lerwick
# Processing Record 31 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 32 of Set 8 | mahajanga
# Processing Record 33 of Set 8 | marsh harbour
# Processing Record 34 of Set 8 | great yarmouth
# Processing Record 35 of Set 8 | jacqueville
# Processing Record 36 of Set 8 | aranos
# Processing Record 37 of Set 8 | mersin
# Processing Record 38 of Set 8 | clairmont
# Processing Record 39 of Set 8 | loveland
# Processing Record 40 of Set 8 | danville
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | bull savanna
# Processing Record 43 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 8 | sobolevo
# Processing Record 46 of Set 8 | provideniya
# Processing Record 47 of Set 8 | san quintin
# Processing Record 48 of Set 8 | ndende
# Processing Record 49 of Set 8 | preobrazheniye
# Processing Record 50 of Set 8 | aswan
# Processing Record 1 of Set 9 | bedford
# Processing Record 2 of Set 9 | uribia
# Processing Record 3 of Set 9 | batagay-alyta
# Processing Record 4 of Set 9 | plouzane
# Processing Record 5 of Set 9 | sanchazi
# Processing Record 6 of Set 9 | bourbonnais
# Processing Record 7 of Set 9 | aneza
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | quebo
# Processing Record 10 of Set 9 | hofn
# Processing Record 11 of Set 9 | fare
# Processing Record 12 of Set 9 | codrington
# Processing Record 13 of Set 9 | namie
# Processing Record 14 of Set 9 | tuatapere
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | manado
# Processing Record 17 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 9 | sinnamary
# Processing Record 19 of Set 9 | ha noi
# Processing Record 20 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 21 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 9 | saryagash
# Processing Record 23 of Set 9 | ponta delgada
# Processing Record 24 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | synya
# Processing Record 26 of Set 9 | anadyr
# Processing Record 27 of Set 9 | narino
# Processing Record 28 of Set 9 | xadani
# City not found. Skipping...
# Processing Record 29 of Set 9 | pevek
# Processing Record 30 of Set 9 | baykit
# Processing Record 31 of Set 9 | andapa
# Processing Record 32 of Set 9 | winneba
# Processing Record 33 of Set 9 | ballina
# Processing Record 34 of Set 9 | karaton
# Processing Record 35 of Set 9 | emerald
# Processing Record 36 of Set 9 | beisfjord
# Processing Record 37 of Set 9 | bend
# Processing Record 38 of Set 9 | kargasok
# Processing Record 39 of Set 9 | borama
# City not found. Skipping...
# Processing Record 40 of Set 9 | basoko
# Processing Record 41 of Set 9 | arraial do cabo
# Processing Record 42 of Set 9 | pangnirtung
# Processing Record 43 of Set 9 | booue
# Processing Record 44 of Set 9 | demyansk
# Processing Record 45 of Set 9 | jalu
# Processing Record 46 of Set 9 | clyde river
# Processing Record 47 of Set 9 | manyana
# Processing Record 48 of Set 9 | manggar
# Processing Record 49 of Set 9 | richmond
# Processing Record 50 of Set 9 | the valley
# Processing Record 1 of Set 10 | kamaishi
# Processing Record 2 of Set 10 | udayagiri
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | road town
# Processing Record 5 of Set 10 | samarai
# Processing Record 6 of Set 10 | ordynskoye
# Processing Record 7 of Set 10 | maridi
# Processing Record 8 of Set 10 | hamilton
# Processing Record 9 of Set 10 | maracaju
# Processing Record 10 of Set 10 | hami
# Processing Record 11 of Set 10 | yenagoa
# Processing Record 12 of Set 10 | donetsk
# Processing Record 13 of Set 10 | matale
# Processing Record 14 of Set 10 | ahuimanu
# Processing Record 15 of Set 10 | novyy oskol
# Processing Record 16 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 10 | chokurdakh
# Processing Record 19 of Set 10 | ilulissat
# Processing Record 20 of Set 10 | mangai
# Processing Record 21 of Set 10 | palmer
# Processing Record 22 of Set 10 | linxia
# Processing Record 23 of Set 10 | huilong
# Processing Record 24 of Set 10 | matara
# Processing Record 25 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 10 | barreiras
# Processing Record 27 of Set 10 | staunton
# Processing Record 28 of Set 10 | strezhevoy
# Processing Record 29 of Set 10 | mogadishu
# Processing Record 30 of Set 10 | xiaoyi
# Processing Record 31 of Set 10 | maniitsoq
# Processing Record 32 of Set 10 | wasilla
# Processing Record 33 of Set 10 | buba
# Processing Record 34 of Set 10 | nador
# Processing Record 35 of Set 10 | orong
# Processing Record 36 of Set 10 | damietta
# Processing Record 37 of Set 10 | walvis bay
# Processing Record 38 of Set 10 | karonga
# Processing Record 39 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 10 | tubmanburg
# Processing Record 41 of Set 10 | nakamura
# Processing Record 42 of Set 10 | mizdah
# Processing Record 43 of Set 10 | saint-pierre
# Processing Record 44 of Set 10 | acarau
# Processing Record 45 of Set 10 | puri
# Processing Record 46 of Set 10 | katangli
# Processing Record 47 of Set 10 | plettenberg bay
# Processing Record 48 of Set 10 | sao paulo de olivenca
# Processing Record 49 of Set 10 | trincomalee
# Processing Record 50 of Set 10 | vagur
# Processing Record 1 of Set 11 | kirakira
# Processing Record 2 of Set 11 | pedernales
# Processing Record 3 of Set 11 | bourail
# Processing Record 4 of Set 11 | timbo
# Processing Record 5 of Set 11 | katete
# Processing Record 6 of Set 11 | macae
# Processing Record 7 of Set 11 | cururupu
# Processing Record 8 of Set 11 | clyde
# Processing Record 9 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 11 | buin
# Processing Record 11 of Set 11 | usulutan
# Processing Record 12 of Set 11 | susehri
# Processing Record 13 of Set 11 | port lincoln
# Processing Record 14 of Set 11 | ancud
# Processing Record 15 of Set 11 | maragogi
# Processing Record 16 of Set 11 | brigantine
# Processing Record 17 of Set 11 | ternate
# Processing Record 18 of Set 11 | clara
# Processing Record 19 of Set 11 | juba
# Processing Record 20 of Set 11 | chulumani
# Processing Record 21 of Set 11 | alamosa
# Processing Record 22 of Set 11 | tobol
# Processing Record 23 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 11 | rawlins
# Processing Record 25 of Set 11 | port moresby
# Processing Record 26 of Set 11 | honningsvag
# Processing Record 27 of Set 11 | pierre
# Processing Record 28 of Set 11 | kabare
# Processing Record 29 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 11 | pangkalanbuun
# Processing Record 32 of Set 11 | rayagada
# Processing Record 33 of Set 11 | saint-dizier
# Processing Record 34 of Set 11 | cervo
# Processing Record 35 of Set 11 | manzanillo
# Processing Record 36 of Set 11 | clovis
# Processing Record 37 of Set 11 | henties bay
# Processing Record 38 of Set 11 | goderich
# Processing Record 39 of Set 11 | alyangula
# Processing Record 40 of Set 11 | te anau
# Processing Record 41 of Set 11 | kudahuvadhoo
# Processing Record 42 of Set 11 | visby
# Processing Record 43 of Set 11 | kupang
# Processing Record 44 of Set 11 | roi et
# Processing Record 45 of Set 11 | tilichiki
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | wangaratta
# Processing Record 48 of Set 11 | ballinrobe
# Processing Record 49 of Set 11 | bayanday
# Processing Record 50 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 12 | nome
# Processing Record 2 of Set 12 | quatre cocos
# Processing Record 3 of Set 12 | angoche
# Processing Record 4 of Set 12 | elban
# Processing Record 5 of Set 12 | acapulco
# Processing Record 6 of Set 12 | mao
# Processing Record 7 of Set 12 | diu
# Processing Record 8 of Set 12 | inuvik
# Processing Record 9 of Set 12 | chambar
# Processing Record 10 of Set 12 | ozerna
# Processing Record 11 of Set 12 | mahebourg
# Processing Record 12 of Set 12 | kalmunai
# Processing Record 13 of Set 12 | necochea
# Processing Record 14 of Set 12 | nicoya
# Processing Record 15 of Set 12 | khorramshahr
# Processing Record 16 of Set 12 | vilyuysk
# Processing Record 17 of Set 12 | kruisfontein
# Processing Record 18 of Set 12 | karlstad
# Processing Record 19 of Set 12 | puerto leguizamo
# Processing Record 20 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 21 of Set 12 | koundara
# Processing Record 22 of Set 12 | malko tarnovo
# Processing Record 23 of Set 12 | miri
# Processing Record 24 of Set 12 | rokiskis
# Processing Record 25 of Set 12 | estevan
# Processing Record 26 of Set 12 | raudeberg
# Processing Record 27 of Set 12 | senigallia
# Processing Record 28 of Set 12 | togur
# Processing Record 29 of Set 12 | vostok
# Processing Record 30 of Set 12 | kloulklubed
# Processing Record 31 of Set 12 | vila franca do campo
# Processing Record 32 of Set 12 | tsuruoka
# Processing Record 33 of Set 12 | betare oya
# Processing Record 34 of Set 12 | san blas
# Processing Record 35 of Set 12 | yerbogachen
# Processing Record 36 of Set 12 | singaparna
# Processing Record 37 of Set 12 | neubrandenburg
# Processing Record 38 of Set 12 | hay river
# Processing Record 39 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 40 of Set 12 | asau
# Processing Record 41 of Set 12 | misratah
# Processing Record 42 of Set 12 | grootfontein
# Processing Record 43 of Set 12 | tabou
# Processing Record 44 of Set 12 | shingu
# Processing Record 45 of Set 12 | prado
# Processing Record 46 of Set 12 | senneterre
# Processing Record 47 of Set 12 | tautira
# Processing Record 48 of Set 12 | pinsk
# Processing Record 49 of Set 12 | puerto colombia
# Processing Record 50 of Set 12 | nago
# Processing Record 1 of Set 13 | lar
# Processing Record 2 of Set 13 | caravelas
# Processing Record 3 of Set 13 | guerrero negro
# Processing Record 4 of Set 13 | aasiaat
# Processing Record 5 of Set 13 | donskoye
# Processing Record 6 of Set 13 | touros
# Processing Record 7 of Set 13 | barra do garcas
# Processing Record 8 of Set 13 | okhotsk
# Processing Record 9 of Set 13 | itoman
# Processing Record 10 of Set 13 | whitehorse
# Processing Record 11 of Set 13 | talara
# Processing Record 12 of Set 13 | tutoia
# Processing Record 13 of Set 13 | salym
# Processing Record 14 of Set 13 | baker city
# Processing Record 15 of Set 13 | lodja
# Processing Record 16 of Set 13 | qaqortoq
# Processing Record 17 of Set 13 | okha
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | teguise
# Processing Record 20 of Set 13 | yanam
# Processing Record 21 of Set 13 | naron
# Processing Record 22 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 13 | gayny
# Processing Record 24 of Set 13 | golden
# Processing Record 25 of Set 13 | port blair
# Processing Record 26 of Set 13 | porto novo
# Processing Record 27 of Set 13 | adrar
# Processing Record 28 of Set 13 | selty
# Processing Record 29 of Set 13 | smithers
# Processing Record 30 of Set 13 | eydhafushi
# Processing Record 31 of Set 13 | akureyri
# Processing Record 32 of Set 13 | lichinga
# Processing Record 33 of Set 13 | dauphin
# Processing Record 34 of Set 13 | peravurani
# Processing Record 35 of Set 13 | malanje
# Processing Record 36 of Set 13 | coihaique
# Processing Record 37 of Set 13 | ekibastuz
# Processing Record 38 of Set 13 | hambantota
# Processing Record 39 of Set 13 | ondangwa
# Processing Record 40 of Set 13 | pampierstad
# Processing Record 41 of Set 13 | alta floresta
# Processing Record 42 of Set 13 | gold coast
# Processing Record 43 of Set 13 | ust-kuyga
# Processing Record 44 of Set 13 | puro
# Processing Record 45 of Set 13 | sabang
# Processing Record 46 of Set 13 | rovaniemi
# Processing Record 47 of Set 13 | merauke
# Processing Record 48 of Set 13 | praia
# Processing Record 49 of Set 13 | altamont
# Processing Record 50 of Set 13 | chik
# Processing Record 1 of Set 14 | hualmay
# Processing Record 2 of Set 14 | viedma
# Processing Record 3 of Set 14 | chimore
# Processing Record 4 of Set 14 | dolgoderevenskoye
# Processing Record 5 of Set 14 | tukrah
# Processing Record 6 of Set 14 | shulan
# Processing Record 7 of Set 14 | chipinge
# Processing Record 8 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 14 | galesong
# Processing Record 10 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 14 | tessalit
# Processing Record 12 of Set 14 | luwingu
# Processing Record 13 of Set 14 | niono
# Processing Record 14 of Set 14 | mirnyy
# Processing Record 15 of Set 14 | port hedland
# Processing Record 16 of Set 14 | suntar
# Processing Record 17 of Set 14 | harper
# Processing Record 18 of Set 14 | diffa
# Processing Record 19 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 14 | burica
# City not found. Skipping...
# Processing Record 21 of Set 14 | dalby
# Processing Record 22 of Set 14 | saint anthony
# Processing Record 23 of Set 14 | aktash
# Processing Record 24 of Set 14 | ca mau
# Processing Record 25 of Set 14 | dong hoi
# Processing Record 26 of Set 14 | hammerfest
# Processing Record 27 of Set 14 | igrim
# Processing Record 28 of Set 14 | minot
# Processing Record 29 of Set 14 | patos
# Processing Record 30 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 14 | puerto ayacucho
# Processing Record 32 of Set 14 | qui nhon
# Processing Record 33 of Set 14 | coahuayana
# Processing Record 34 of Set 14 | high rock
# Processing Record 35 of Set 14 | esil
# Processing Record 36 of Set 14 | micheweni
# Processing Record 37 of Set 14 | de-kastri
# Processing Record 38 of Set 14 | salinopolis
# Processing Record 39 of Set 14 | rosarito
# Processing Record 40 of Set 14 | smolenka
# Processing Record 41 of Set 14 | tres passos
# Processing Record 42 of Set 14 | tres arroyos
# Processing Record 43 of Set 14 | la maddalena
# Processing Record 44 of Set 14 | novodugino
# Processing Record 45 of Set 14 | muhos
# Processing Record 46 of Set 14 | mangaluru
# Processing Record 47 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 48 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | olafsvik
# Processing Record 1 of Set 15 | kitgum
# Processing Record 2 of Set 15 | bugulma
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | chicama
# Processing Record 5 of Set 15 | macusani
# Processing Record 6 of Set 15 | vrangel
# Processing Record 7 of Set 15 | manokwari
# Processing Record 8 of Set 15 | temirtau
# Processing Record 9 of Set 15 | sagua la grande
# Processing Record 10 of Set 15 | bathsheba
# Processing Record 11 of Set 15 | raga
# Processing Record 12 of Set 15 | nizhneudinsk
# Processing Record 13 of Set 15 | alekseyevka
# Processing Record 14 of Set 15 | olot
# Processing Record 15 of Set 15 | matadi
# Processing Record 16 of Set 15 | purpe
# Processing Record 17 of Set 15 | beloha
# Processing Record 18 of Set 15 | riom
# Processing Record 19 of Set 15 | northam
# Processing Record 20 of Set 15 | dicabisagan
# Processing Record 21 of Set 15 | carballo
# Processing Record 22 of Set 15 | omsukchan
# Processing Record 23 of Set 15 | palu
# Processing Record 24 of Set 15 | puerto escondido
# Processing Record 25 of Set 15 | kemin
# Processing Record 26 of Set 15 | pilar
# Processing Record 27 of Set 15 | krasne
# Processing Record 28 of Set 15 | verkhoyansk
# Processing Record 29 of Set 15 | marienburg
# Processing Record 30 of Set 15 | birjand
# Processing Record 31 of Set 15 | coron
# Processing Record 32 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 15 | simao
# Processing Record 34 of Set 15 | mocuba
# Processing Record 35 of Set 15 | simplicio mendes
# Processing Record 36 of Set 15 | beyneu
# Processing Record 37 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 15 | nara
# Processing Record 39 of Set 15 | perehonivka
# Processing Record 40 of Set 15 | george town
# Processing Record 41 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 15 | terrace
# Processing Record 43 of Set 15 | banjar
# Processing Record 44 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 15 | strathmore
# Processing Record 46 of Set 15 | erenhot
# Processing Record 47 of Set 15 | quijingue
# Processing Record 48 of Set 15 | korla
# Processing Record 49 of Set 15 | lagoa
# Processing Record 50 of Set 15 | tooele
# Processing Record 1 of Set 16 | ipixuna
# Processing Record 2 of Set 16 | bandarbeyla
# Processing Record 3 of Set 16 | mecca
# Processing Record 4 of Set 16 | kalomo
# City not found. Skipping...
# Processing Record 5 of Set 16 | torbat-e jam
# Processing Record 6 of Set 16 | conceicao da barra
# Processing Record 7 of Set 16 | xining
# Processing Record 8 of Set 16 | amapa
# Processing Record 9 of Set 16 | kaseda
# Processing Record 10 of Set 16 | ishigaki
# Processing Record 11 of Set 16 | miranda
# Processing Record 12 of Set 16 | vanavara
# Processing Record 13 of Set 16 | brewster
# Processing Record 14 of Set 16 | keti bandar
# Processing Record 15 of Set 16 | greencastle
# Processing Record 16 of Set 16 | asbe teferi
# Processing Record 17 of Set 16 | umm lajj
# Processing Record 18 of Set 16 | kieta
# Processing Record 19 of Set 16 | naifaru
# Processing Record 20 of Set 16 | mitsamiouli
# Processing Record 21 of Set 16 | lloydminster
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Tiksi  71.69  128.87     18.46        96         100       18.01
# 1       Ushuaia -54.80  -68.30     46.40        71          40       18.34
# 2        Camalu  30.85 -116.07     84.00        19          22        1.01
# 3     Roebourne -20.78  117.13     66.99        72           0       12.97
# 4   Springfield  37.22  -93.30     57.00        87          90        6.93
# 5       Mataura -46.19  168.86     46.99        92         100        1.01
# 6           Vao -22.67  167.48     70.99        81          36       18.70
# 7         Asosa  10.07   34.53     61.45        99          11        2.42
# 8         Alofi -19.06 -169.92     77.00        94          89        3.36
# 9  Punta Arenas -53.15  -70.92     46.40        65          75       24.16
#
#   Country                 Date       Description
# 0      RU  2020-10-18 17:32:19        light snow
# 1      AR  2020-10-18 17:27:42  scattered clouds
# 2      MX  2020-10-18 17:32:20        few clouds
# 3      AU  2020-10-18 17:32:20         clear sky
# 4      US  2020-10-18 17:28:58              mist
# 5      NZ  2020-10-18 17:32:21        light rain
# 6      NC  2020-10-18 17:32:21  scattered clouds
# 7      ET  2020-10-18 17:32:21        few clouds
# 8      NU  2020-10-18 17:32:22   overcast clouds
# 9      CL  2020-10-18 17:27:59     broken clouds

# %%
city_data_df.to_csv('weather_database\WeatherPy_Database.csv', index = "False")
